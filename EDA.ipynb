# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data.csv",encoding = 'ISO-8859-1',parse_dates=["InvoiceDate"])
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
d={
        'InvoiceNo': 'invoice_num',
        'StockCode' : 'stock_code',
        'Description' : 'description',
        'Quantity' : 'quantity',
        'InvoiceDate' : 'invoice_date',
        'UnitPrice' : 'unit_price',
        'CustomerID' : 'cust_id',
        'Country' : 'country'}
df.rename(columns=d,inplace=True)

# %%
list(df.columns)
# Out:
# ['invoice_num',
#  'stock_code',
#  'description',
#  'quantity',
#  'invoice_date',
#  'unit_price',
#  'cust_id',
#  'country']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  datetime64[ns]
#  5   unit_price    541909 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isna()
# Out:
#         invoice_num  stock_code  description  quantity  invoice_date  \
# 0             False       False        False     False         False
# 1             False       False        False     False         False
# 2             False       False        False     False         False
# 3             False       False        False     False         False
# 4             False       False        False     False         False
# ...             ...         ...          ...       ...           ...
# 541904        False       False        False     False         False
# 541905        False       False        False     False         False
# 541906        False       False        False     False         False
# 541907        False       False        False     False         False
# 541908        False       False        False     False         False
#
#         unit_price  cust_id  country
# 0            False    False    False
# 1            False    False    False
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %%
df.description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: object

# %%
df["description"]=df.description.str.lower()

# %%
df.head(10)
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
# 5      536365      22752         set 7 babushka nesting boxes         2
# 6      536365      21730    glass star frosted t-light holder         6
# 7      536366      22633               hand warmer union jack         6
# 8      536366      22632            hand warmer red polka dot         6
# 9      536367      84879        assorted colour bird ornament        32
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %%
df_new=df.dropna()

# %%
df_new.isna().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %%
df_new.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
df_new.tail(2)
# Out:
#        invoice_num stock_code                      description  quantity  \
# 541907      581587      23255  childrens cutlery circus parade         4
# 541908      581587      22138    baking set 9 piece retrospot          3
#
#               invoice_date  unit_price  cust_id country
# 541907 2011-12-09 12:50:00        4.15  12680.0  France
# 541908 2011-12-09 12:50:00        4.95  12680.0  France

# %%
df_new.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                float64
# country                 object
# dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')
df_new["cust_id"]=df_new["cust_id"].astype('int')

# %%
df_new.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# cust_id                  int64
# country                 object
# dtype: object

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price    cust_id
# count  406829.00                         406829   406829.00  406829.00
# mean       12.06  2011-07-10 16:30:57.879207424        3.46   15287.69
# min    -80995.00            2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00            2011-04-06 15:02:00        1.25   13953.00
# 50%         5.00            2011-07-31 11:48:00        1.95   15152.00
# 75%        12.00            2011-10-20 13:06:00        3.75   16791.00
# max     80995.00            2011-12-09 12:50:00    38970.00   18287.00
# std       248.69                            NaN       69.32    1713.60

# %%
a=[1,2,3,4,5,-1,-2]
for value in a:
   if value>0:
       print(value)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
cond=df_new["quantity"]>0

# %%
df_new =df_new[cond]

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  397924.000000                         397924  397924.000000
# mean       13.021823  2011-07-10 23:43:36.912475648       3.116174
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 11:12:00       1.250000
# 50%         6.000000            2011-07-31 14:39:00       1.950000
# 75%        12.000000            2011-10-20 14:33:00       3.750000
# max     80995.000000            2011-12-09 12:50:00    8142.750000
# std       180.420210                            NaN      22.096788
#
#              cust_id
# count  397924.000000
# mean    15294.315171
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.169877

# %%
df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  white hanging heart t-light holder         6
# 1      536365      71053                 white metal lantern         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
df_new["amount_spent"]=df["quantity"]*df["unit_price"]

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %%
df_new.shape
# Out:
# (397924, 9)

# %%
df_new.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country', 'amount_spent'],
#       dtype='object')

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %%
col_order = ['invoice_num','invoice_date','stock_code','description','quantity','unit_price','amount_spent','cust_id','country']

# %%
df_new = df_new[col_order]

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
df_new.shape
# Out:
# (397924, 9)

# %%
df_new["invoice_date"].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: invoice_date, Length: 397924, dtype: int32

# %%
df_new["invoice_date"].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %%
df_new.head(2)
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom

# %%
y=2010
m=12
y_m=2010*100+12

# %%
y_m
# Out:
# 201012

# %%
c1="year_month"

# %%
v1=df_new["invoice_date"].map(lambda col:100*(col.year)+col.month)

# %%
df_new.insert( 2,  c1,  v1)

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month stock_code  \
# 0           536365 2010-12-01 08:26:00      201012     85123A
# 1           536365 2010-12-01 08:26:00      201012      71053
# 2           536365 2010-12-01 08:26:00      201012     84406B
# 3           536365 2010-12-01 08:26:00      201012     84029G
# 4           536365 2010-12-01 08:26:00      201012     84029E
# ...            ...                 ...         ...        ...
# 541904      581587 2011-12-09 12:50:00      201112      22613
# 541905      581587 2011-12-09 12:50:00      201112      22899
# 541906      581587 2011-12-09 12:50:00      201112      23254
# 541907      581587 2011-12-09 12:50:00      201112      23255
# 541908      581587 2011-12-09 12:50:00      201112      22138
#
#                                 description  quantity  unit_price  \
# 0        white hanging heart t-light holder         6        2.55
# 1                       white metal lantern         6        3.39
# ...

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     85123A
# 1      536365 2010-12-01 08:26:00      201012      71053
# 2      536365 2010-12-01 08:26:00      201012     84406B
# 3      536365 2010-12-01 08:26:00      201012     84029G
# 4      536365 2010-12-01 08:26:00      201012     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
df_new["invoice_date"].dt.weekday
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 541904    4
# 541905    4
# 541906    4
# 541907    4
# 541908    4
# Name: invoice_date, Length: 397924, dtype: int32

# %%
c3="day"

# %%
v3=df_new["invoice_date"].dt.weekday+1

# %%
df_new.insert(3,c3,v3)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
list(df_new.columns)
# Out:
# ['invoice_num',
#  'invoice_date',
#  'year_month',
#  'day',
#  'stock_code',
#  'description',
#  'quantity',
#  'unit_price',
#  'amount_spent',
#  'cust_id',
#  'country']

# %%
df_new.groupby(["cust_id"]).count()
# Out:
#          invoice_num  invoice_date  year_month  day  stock_code  description  \
# cust_id
# 12346              1             1           1    1           1            1
# 12347            182           182         182  182         182          182
# 12348             31            31          31   31          31           31
# 12349             73            73          73   73          73           73
# 12350             17            17          17   17          17           17
# ...              ...           ...         ...  ...         ...          ...
# 18280             10            10          10   10          10           10
# 18281              7             7           7    7           7            7
# 18282             12            12          12   12          12           12
# 18283            756           756         756  756         756          756
# 18287             70            70          70   70          70           70
#
# ...

# %%
cols=["cust_id","country"]

# %%
df_new.groupby(cols).count()
# Out:
#                         invoice_num  invoice_date  year_month  day  \
# cust_id country
# 12346   United Kingdom            1             1           1    1
# 12347   Iceland                 182           182         182  182
# 12348   Finland                  31            31          31   31
# 12349   Italy                    73            73          73   73
# 12350   Norway                   17            17          17   17
# ...                             ...           ...         ...  ...
# 18280   United Kingdom           10            10          10   10
# 18281   United Kingdom            7             7           7    7
# 18282   United Kingdom           12            12          12   12
# 18283   United Kingdom          756           756         756  756
# 18287   United Kingdom           70            70          70   70
#
#                         stock_code  description  quantity  unit_price  \
# cust_id country
# ...

# %%
cols=["cust_id","country"]

# %%
df_new.groupby(cols,as_index=False)["invoice_num"].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
df_new.groupby(cols,as_index=False)["invoice_num"].count().head()
# Out:
#    cust_id         country  invoice_num
# 0    12346  United Kingdom            1
# 1    12347         Iceland          182
# 2    12348         Finland           31
# 3    12349           Italy           73
# 4    12350          Norway           17

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new.groupby(cols, as_index=False)['invoice_num'].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders = df_new.groupby(cols, as_index=False)['invoice_num'].count()

# %%
orders
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders.sort_values("invoice_num",ascending=False)
# Out:
#       cust_id         country  invoice_num
# 4019    17841  United Kingdom         7847
# 1888    14911            EIRE         5677
# 1298    14096  United Kingdom         5111
# 334     12748  United Kingdom         4596
# 1670    14606  United Kingdom         2700
# ...       ...             ...          ...
# 2567    15823  United Kingdom            1
# 4333    18268  United Kingdom            1
# 4310    18233  United Kingdom            1
# 4271    18184  United Kingdom            1
# 0       12346  United Kingdom            1
#
# [4347 rows x 3 columns]

# %%
orders = df_new.groupby(cols, as_index=False)['invoice_num'].count()
plt.subplots(figsize=(15,6))

plt.plot(orders.cust_id, orders.invoice_num)

plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
cols=["cust_id","country"]

# %%
df_new.groupby(cols)["amount_spent"].sum()
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
#                              ...
# 18280    United Kingdom      180.60
# 18281    United Kingdom       80.82
# 18282    United Kingdom      178.05
# 18283    United Kingdom     2094.88
# 18287    United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %%
df_new.groupby(cols,as_index=False)["amount_spent"].sum()
# Out:
#       cust_id         country  amount_spent
# 0       12346  United Kingdom      77183.60
# 1       12347         Iceland       4310.00
# 2       12348         Finland       1797.24
# 3       12349           Italy       1757.55
# 4       12350          Norway        334.40
# ...       ...             ...           ...
# 4342    18280  United Kingdom        180.60
# 4343    18281  United Kingdom         80.82
# 4344    18282  United Kingdom        178.05
# 4345    18283  United Kingdom       2094.88
# 4346    18287  United Kingdom       1837.28
#
# [4347 rows x 3 columns]

# %%
money_spent=df_new.groupby(cols,as_index=False)["amount_spent"].sum()

# %%
money_spent
# Out:
#       cust_id         country  amount_spent
# 0       12346  United Kingdom      77183.60
# 1       12347         Iceland       4310.00
# 2       12348         Finland       1797.24
# 3       12349           Italy       1757.55
# 4       12350          Norway        334.40
# ...       ...             ...           ...
# 4342    18280  United Kingdom        180.60
# 4343    18281  United Kingdom         80.82
# 4344    18282  United Kingdom        178.05
# 4345    18283  United Kingdom       2094.88
# 4346    18287  United Kingdom       1837.28
#
# [4347 rows x 3 columns]

# %%
money_spent.sort_values(by="amount_spent",ascending=False).head(10)
# Out:
#       cust_id         country  amount_spent
# 1698    14646     Netherlands     280206.02
# 4210    18102  United Kingdom     259657.30
# 3737    17450  United Kingdom     194550.79
# 3017    16446  United Kingdom     168472.50
# 1888    14911            EIRE     143825.06
# 57      12415       Australia     124914.53
# 1342    14156            EIRE     117379.63
# 3780    17511  United Kingdom      91062.38
# 2711    16029  United Kingdom      81024.84
# 0       12346  United Kingdom      77183.60

# %%
money_spent=df_new.groupby(cols,as_index=False)["amount_spent"].sum()
plt.subplots(figsize=(15,6))

plt.plot(money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
color = sns.color_palette()

# %%
df_new.groupby("invoice_num")["year_month"].unique()
# Out:
# invoice_num
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 581583    [201112]
# 581584    [201112]
# 581585    [201112]
# 581586    [201112]
# 581587    [201112]
# Name: year_month, Length: 18536, dtype: object

# %%
df_new.groupby("invoice_num")["year_month"].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
df_new.groupby("invoice_num")["year_month"].unique().value_counts().sort_values()
# Out:
# year_month
# [201112]     778
# [201101]     987
# [201102]     998
# [201104]    1149
# [201108]    1281
# [201103]    1321
# [201107]    1331
# [201106]    1393
# [201012]    1400
# [201105]    1555
# [201109]    1756
# [201110]    1929
# [201111]    2658
# Name: count, dtype: int64

# %%
df_new.groupby("invoice_num")["year_month"].unique().value_counts().sort_values(ascending=False)
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
df_new.groupby("invoice_num")["year_month"].unique().value_counts().sort_values(ascending=False).sort_index()
# Out:
# year_month
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: count, dtype: int64

# %%
ax = df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index().plot(kind = 'bar',color = color[0],figsize = (15,6))

ax.set_xlabel('Month and Year',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)', fontsize = 15)

t = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11')

ax.set_xticklabels(t, rotation='horizontal', fontsize=13)

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
df_new.groupby("invoice_num")["day"].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
df_new.groupby("invoice_num")["day"].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby("invoice_num")["day"].unique().value_counts().sort_values(ascending=False)
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby("invoice_num")["day"].unique().value_counts().sort_values(ascending=False).sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
ax = df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(kind = 'bar',color=color[0],figsize=(15,6))

ax.set_xlabel('Day',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Days',fontsize=15)
d = ('Mon','Tue','Wed','Thur','Fri','Sun')
ax.set_xticklabels(d, rotation='horizontal', fontsize=15)
plt.show()

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %%
# check the distribution of unit price
plt.subplots(figsize = (12,6))

sns.boxplot(df_new.unit_price)
plt.show()

# %%
df_free = df_new[df_new.unit_price == 0]

# %%
len(df_free)
# Out:
# 40

# %%
df_free.year_month
# Out:
# 9302      201012
# 33576     201012
# 40089     201012
# 47068     201101
# 47070     201101
# 56674     201101
# 86789     201102
# 130188    201103
# 139453    201103
# 145208    201104
# 157042    201104
# 187613    201105
# 198383    201105
# 279324    201107
# 282912    201107
# 285657    201108
# 298054    201108
# 314745    201108
# 314746    201108
# 314747    201108
# 314748    201108
# 358655    201109
# 361825    201109
# 379913    201110
# 395529    201110
# 420404    201110
# 436428    201111
# 436597    201111
# 436961    201111
# 439361    201111
# 446125    201111
# 446793    201111
# 446794    201111
# 454463    201111
# 454464    201111
# 479079    201111
# 479546    201111
# 480649    201111
# 485985    201111
# 502122    201111
# Name: year_month, dtype: int64

# %%
df_free.year_month.value_counts()
# Out:
# year_month
# 201111    14
# 201108     6
# 201012     3
# 201110     3
# 201101     3
# 201107     2
# 201103     2
# 201104     2
# 201105     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free.year_month.value_counts().sort_values(ascending=False)
# Out:
# year_month
# 201111    14
# 201108     6
# 201012     3
# 201110     3
# 201101     3
# 201107     2
# 201103     2
# 201104     2
# 201105     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free.year_month.value_counts().sort_values(ascending=False).sort_index()
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
ax=df_free.year_month.value_counts().sort_values(ascending=False).sort_index().plot(kind = 'bar',figsize=(12,6), color=color[0])
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)

m = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11')

ax.set_xticklabels(m, rotation='horizontal', fontsize=13)
plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012    3     85123A
# 1      536365 2010-12-01 08:26:00      201012    3      71053
# 2      536365 2010-12-01 08:26:00      201012    3     84406B
# 3      536365 2010-12-01 08:26:00      201012    3     84029G
# 4      536365 2010-12-01 08:26:00      201012    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# ...

# %%
df_new.groupby("country")["invoice_date"].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
df_new.groupby("country")["invoice_date"].count().sort_values(ascending=False)
# Out:
# country
# United Kingdom          354345
# Germany                   9042
# France                    8342
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# ...

# %%
group_country_orders=df_new.groupby("country")["invoice_date"].count().sort_values(ascending=False)
# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders=df_new.groupby("country")["invoice_date"].count().sort_values(ascending=False)
del group_country_orders["United Kingdom"]
# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind = 'barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
# these is called Data Analysis Project(EDA)
